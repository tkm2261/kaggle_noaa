# %%
# %matplotlib inline
from IPython.core.display import display
import matplotlib.pyplot as plt
import pickle
import pandas
import numpy
import cv2
from PIL import Image
from tqdm import tqdm_notebook as tqdm
import skimage.feature
DATA_DIR = "../../data/data/"
TRAIN_DATA_DIR = DATA_DIR + "Train/"

# %%
pred = numpy.loadtxt("tmp.npy")

# %%
plt.imshow(pred)

# %%
pred.sum()
# Out:
# 0.0

# %%
im = Image.open("../../data/data/Test/11134.jpg", "r")
im = numpy.array(im)
plt.imshow(im)

# %%
from load_data import split_batch, load_data
df = pandas.read_csv(TRAIN_DATA_DIR + 'train.csv')                                                                                                                                                                                                                              
list_batchs = split_batch(df.train_id.values, batch_size=10)                                                                                                                                                                                                            
                                                                                                                                                                                                                                                                                
                                                                                                                                                                                                                                                                                
def data_gen():                                                                                                                                                                                                                                                                 
    while 1:                                                                                                                                                                                                                                                                    
        for batch in list_batchs:                                                                                                                                                                                                                                               
            yield load_data(batch)

# %%
a = data_gen()

# %%
x, y = next(a)

# %%
plt.imshow(y[0][:, :, 0])

# %%
plt.imshow(x[0])
